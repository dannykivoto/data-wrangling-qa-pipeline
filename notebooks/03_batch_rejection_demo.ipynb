# %% [markdown]
# # Batch Rejection Demo\nShow how an invalid batch is quarantined when timestamp leakage is too high.

# %%
import pandas as pd\ndf = pd.read_csv('../data/raw/synthetic_logs_batch_002.csv')\n((pd.to_datetime(df['action_timestamp']) < pd.to_datetime(df['account_created'])).mean())
