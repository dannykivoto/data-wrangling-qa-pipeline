# %% [markdown]
# # Initial EDA\nQuick surface analysis for messy software logs using Pandas and Polars.

# %%
import pandas as pd\nimport polars as pl\ndf = pd.read_csv('../data/raw/synthetic_logs_batch_001.csv')\ndf.head()

# %%
df.isna().mean().sort_values(ascending=False)
