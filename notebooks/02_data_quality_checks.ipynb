# %% [markdown]
# # Data Quality Checks\nFlag duplicates, missing IDs, and impossible timestamps.

# %%
import pandas as pd\nfrom src.validate import add_validation_flags\ndf = pd.read_csv('../data/raw/synthetic_logs_batch_001.csv')\nvalidated = add_validation_flags(df)\nvalidated[['flag_time_violation','flag_duplicate','flag_missing_user_id']].sum()
